# %%
patients={}
def add_patients():
    patients_id=input("Enter your ID")
    name=input("Enter your name")
    age=int(input("Enter your age"))
    disease=input("Enter a disease")

    patients[patients_id] = {
        "Name":name,
        "Age":age,
        "Disease":disease }

    print("Added Patients Details")

def view_patients():
    if not patients:
        print("No patients found")
    else:
        for pid , details in patients.items():
            print("\nPatients_id",pid)
            print("Name:",details["Name"])
            print("Age:",details["Age"])
            print("Disease:",details["Disease"])

def search_id ():
    paitent_id=input("Enter your id")

    if search_id in patients:
        print("Patients Founded")
        print("Name:", patients[patient_id]["Name"])
        print("Age:", patients[patient_id]["Age"])
        print("Disease:", patients[patient_id]["Disease"])

    else:
        print("Patient not founded")

def delete_patient():
    patient_id = input("Enter Patient ID to Delete: ")

    if patient_id in patients:
        del patients[patient_id]
        print("Patient Deleted Successfully!")
    else:
        print("Patient Not Found!")

def menu():
    while True:
        print("\n===== HOSPITAL MANAGEMENT SYSTEM =====")
        print("1. Add Patient")
        print("2. View Patients")
        print("3. Search Patient")
        print("4. Delete Patient")
        print("5. Exit")

        choice = input("Enter Your Choice: ")

        if choice == "1":
            add_patients()

        elif choice == "2":
            view_patients()

        elif choice == "3":
            search_id()

        elif choice == "4":
            delete_patient()

        elif choice == "5":
            print("Thank You!")
            break

        else:
            print("Invalid Choice!")

menu()
# Out:
# ===== HOSPITAL MANAGEMENT SYSTEM =====
# 1. Add Patient
# 2. View Patients
# 3. Search Patient
# 4. Delete Patient
# 5. Exit
