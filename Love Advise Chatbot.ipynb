# %%
print("Welcom Love Advise Chatbot")
while True:
    user=input("Can i help you")
    if user == "Single":
        print("You Want to be Mingle")
    elif user == "Couple":
        print("Couples Problem ?")
    elif user == "Yes Want to be mingle":
        print("Okay Go to propose ")
    elif user == "Yes Couple problem":
        print("Go to Talk And Solve it")
    elif user == "Okay":
        print("Yes , Goodbye")
    else :
        print("Sorry Try Again")
# Out:
# Welcom Love Advise Chatbot
# Can i help you Single
# You Want to be Mingle
# Can i help you Yes Want to be mingle
# Okay Go to propose
# Can i help you okayy
# Sorry Try Again
# Can i help you okay
# Sorry Try Again
# Can i help you Okay
# Yes , Goodbye
# Can i help you Couple
# Couples Problem ?
